# %%
import pandas as pd

# %%
#Agencies 1960-1999
ds1 = pd.read_csv("../Data/ds1.csv")

# %%
ds1.head()
# Out:
#    data_year        ori legacy_ori covered_by_legacy_ori  \
# 0       1960  AK0010100  AK0010100                   NaN
# 1       1960  AK0010200  AK0010200                   NaN
# 2       1960  AK0010300  AK0010300                   NaN
# 3       1960  AK0010400  AK0010400                   NaN
# 4       1960  AK0010500  AK0010500                   NaN
#
#   direct_contributor_flag dormant_flag  dormant_year reporting_type  \
# 0                       N            N           NaN              S
# 1                       N            N           NaN              S
# 2                       N            N           NaN              S
# 3                       N            N           NaN              S
# 4                       N            N           NaN              S
#
#   ucr_agency_name ncic_agency_name  ... nibrs_off_eth_start_date covered_flag  \
# 0       ANCHORAGE     ANCHORAGE PD  ...                      NaN            N
# ...

# %%
#Agencies 2000-2020
ds2 = pd.read_csv("../Data/ds2.csv")

# %%
ds2.head()
# Out:
#    data_year        ori legacy_ori covered_by_legacy_ori  \
# 0       2000  AK0010100  AK0010100                   NaN
# 1       2000  AK0010200  AK0010200                   NaN
# 2       2000  AK0010300  AK0010300                   NaN
# 3       2000  AK0010400  AK0010400                   NaN
# 4       2000  AK0010500  AK0010500                   NaN
#
#   direct_contributor_flag dormant_flag  dormant_year reporting_type  \
# 0                       N            N           NaN              S
# 1                       N            N           NaN              S
# 2                       N            N           NaN              S
# 3                       N            N           NaN              S
# 4                       N            N           NaN              S
#
#   ucr_agency_name ncic_agency_name  ... nibrs_off_eth_start_date covered_flag  \
# 0       ANCHORAGE     ANCHORAGE PD  ...                      NaN            N
# ...
